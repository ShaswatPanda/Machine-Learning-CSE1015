# %%
### Shaswat Panda 
### 19BAI1047
### Kunal Makwana 
### 19BAI1011
### Kunal Makwana 
### 19BAI1011
### Prakriti Singh
### 19BAI1139
### Arjun Tandon
### 19BAI1146
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
chal = pd.read_excel("data_chall.xlsx")

# %%
chal
# Out:
#     Sample Number   X1  X2  X3         Y2  Z1
# 0               1   50   6  30   4.855400  18
# 1               2   50   6  45   4.966500  19
# 2               3   50   6  60   5.793300  20
# 3               4   50   6  75   6.282900  27
# 4               5   50   8  30   5.064000  19
# ..            ...  ...  ..  ..        ...  ..
# 59             60  200  10  75   9.534520  37
# 60             61  200  12  30   8.084280  39
# 61             62  200  12  45   8.952733  44
# 62             63  200  12  60   8.861120  43
# 63             64  200  12  75  10.126740  38
#
# [64 rows x 6 columns]

# %%
var1 = chal['X1'].to_numpy()

# %%
var1
# Out:
# array([ 50,  50,  50,  50,  50,  50,  50,  50,  50,  50,  50,  50,  50,
#         50,  50,  50, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
#        100, 100, 100, 100, 100, 100, 150, 150, 150, 150, 150, 150, 150,
#        150, 150, 150, 150, 150, 150, 150, 150, 150, 200, 200, 200, 200,
#        200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200])

# %%
var2 = chal['X2'].to_numpy()

# %%
var2
# Out:
# array([ 6,  6,  6,  6,  8,  8,  8,  8, 10, 10, 10, 10, 12, 12, 12, 12,  6,
#         6,  6,  6,  8,  8,  8,  8, 10, 10, 10, 10, 12, 12, 12, 12,  6,  6,
#         6,  6,  8,  8,  8,  8, 10, 10, 10, 10, 12, 12, 12, 12,  6,  6,  6,
#         6,  8,  8,  8,  8, 10, 10, 10, 10, 12, 12, 12, 12])

# %%
np.corrcoef(var1,var2)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
var3 = chal['X3'].to_numpy()

# %%
var3
# Out:
# array([30, 45, 60, 75, 30, 45, 60, 75, 30, 45, 60, 75, 30, 45, 60, 75, 30,
#        45, 60, 75, 30, 45, 60, 75, 30, 45, 60, 75, 30, 45, 60, 75, 30, 45,
#        60, 75, 30, 45, 60, 75, 30, 45, 60, 75, 30, 45, 60, 75, 30, 45, 60,
#        75, 30, 45, 60, 75, 30, 45, 60, 75, 30, 45, 60, 75])

# %%
np.corrcoef(var1,var3)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
np.corrcoef(var2,var3)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
y2 = chal['Y2'].to_numpy()

# %%
np.corrcoef(var1,y2)
# Out:
# array([[1.        , 0.37471011],
#        [0.37471011, 1.        ]])

# %%
np.corrcoef(var2,y2)
# Out:
# array([[1.        , 0.39209061],
#        [0.39209061, 1.        ]])

# %%
np.corrcoef(var3,y2)
# Out:
# array([[1.        , 0.66235199],
#        [0.66235199, 1.        ]])

# %%
y2 = chal['Y2'].to_numpy()

# %%
z1 = chal['Z1'].to_numpy()

# %%
z1
# Out:
# array([18, 19, 20, 27, 19, 24, 21, 23, 20, 20, 21, 24, 21, 22, 29, 25, 24,
#        24, 26, 27, 29, 27, 29, 27, 27, 29, 31, 32, 31, 31, 32, 33, 32, 33,
#        32, 36, 35, 33, 32, 38, 32, 33, 33, 33, 34, 35, 38, 38, 33, 34, 34,
#        32, 38, 39, 37, 42, 41, 36, 38, 37, 39, 44, 43, 38])

# %%
np.corrcoef(y2,z1)
# Out:
# array([[1.        , 0.55381959],
#        [0.55381959, 1.        ]])

# %%
np.corrcoef(var1,z1)
# Out:
# array([[1.       , 0.8942364],
#        [0.8942364, 1.       ]])

# %%
np.corrcoef(var2,z1)
# Out:
# array([[1.        , 0.25428523],
#        [0.25428523, 1.        ]])

# %%
np.corrcoef(var3,z1)
# Out:
# array([[1.        , 0.13773783],
#        [0.13773783, 1.        ]])

# %%
plt.scatter(var1,y2)

# %%
plt.scatter(var2,y2)

# %%
plt.scatter(var3,y2)

# %%
plt.scatter(var1,z1)

# %%
plt.scatter(var2,z1)

# %%
plt.scatter(var3,z1)

# %%
plt.scatter(y2,z1)

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Multiple Linear Regression

# %%
X = chal[['X1','X2','X3']]
Y = chal['Y2']
Z = chal['Z1']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=103)

# %%
X_train
# Out:
#      X1  X2  X3
# 1    50   6  45
# 55  200   8  75
# 15   50  12  75
# 61  200  12  45
# 41  150  10  45
# 38  150   8  60
# 39  150   8  75
# 50  200   6  60
# 14   50  12  60
# 63  200  12  75
# 46  150  12  60
# 11   50  10  75
# 40  150  10  30
# 53  200   8  45
# 5    50   8  45
# 52  200   8  30
# 0    50   6  30
# 54  200   8  60
# 37  150   8  45
# 17  100   6  45
# 29  100  12  45
# 8    50  10  30
# 59  200  10  75
# 10   50  10  60
# 33  150   6  45
# 13   50  12  45
# 58  200  10  60
# 26  100  10  60
# 45  150  12  45
# 20  100   8  30
# 31  100  12  75
# 12   50  12  30
# 43  150  10  75
# 23  100   8  75
# 44  150  12  30
# 21  100   8  45
# 28  100  12  30
# 49  200   6  45
# 6    50   8  60
# 57  200  10  45
# 27  100  10  75
# 19  100   6  75
# 9    50  10  45
# 7    50   8  75

# %%
y_train
# Out:
# 1      4.966500
# 55     9.315850
# 15     9.099100
# 61     8.952733
# 41     7.191133
# 38     7.148000
# 39     9.213267
# 50     6.834840
# 14     7.713600
# 63    10.126740
# 46     8.605340
# 11     8.891850
# 40     6.988440
# 53     7.234333
# 5      5.196200
# 52     6.261340
# 0      4.855400
# 54     7.324250
# 37     7.122467
# 17     6.960600
# 29     8.109800
# 8      5.781000
# 59     9.534520
# 10     6.612200
# 33     7.076500
# 13     7.054800
# 58     7.751060
# 26     7.385900
# 45     7.762120
# 20     6.937600
# 31     9.665860
# 12     6.594200
# 43     9.438567
# 23     9.232500
# 44     7.871333
# 21     6.960900
# 28     7.702450
# 49     6.969200
# 6      5.914400
# 57     7.225680
# 27     9.387400
# 19     9.164200
# 9      5.895767
# 7      8.649900
# Name: Y2, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('intercept:', regressor.intercept_)
# Out:
# intercept: 1.254961992847159

# %%
print('slope:', regressor.coef_)
# Out:
# slope: [0.00722792 0.25443675 0.05795036]

# %%
regressor.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': False,
#  'positive': False}

# %%
y_pred = regressor.predict(X_test) 
y_pred
# Out:
# array([8.36053841, 5.60428066, 7.48925517, 6.61999979, 6.11315416,
#        8.50801609, 7.49229696, 8.5734426 , 7.12988722, 6.98139561,
#        7.34279142, 9.23080771, 6.26063184, 6.98342346, 5.39036254,
#        7.4902691 , 5.96567647, 9.73866728, 8.21204679, 5.24288485])

# %%
X_test
# Out:
#      X1  X2  X3
# 42  150  10  60
# 32  150   6  30
# 3    50   6  75
# 2    50   6  60
# 36  150   8  30
# 30  100  12  60
# 60  200  12  30
# 51  200   6  75
# 25  100  10  45
# 18  100   6  60
# 34  150   6  60
# 62  200  12  60
# 24  100  10  30
# 56  200  10  30
# 4    50   8  30
# 22  100   8  60
# 48  200   6  30
# 47  150  12  75
# 35  150   6  75
# 16  100   6  30

# %%
y_test
# Out:
# 42    7.329667
# 32    7.073000
# 3     6.282900
# 2     5.793300
# 36    6.117820
# 30    8.555750
# 60    8.084280
# 51    9.136967
# 25    7.018700
# 18    7.086350
# 34    6.822700
# 62    8.861120
# 24    6.958450
# 56    6.974480
# 4     5.064000
# 22    7.244300
# 48    6.993700
# 47    9.768640
# 35    9.263050
# 16    6.949200
# Name: Y2, dtype: float64

# %%
plt.scatter(y_pred, y_test, color='red') 
plt.title("Challenging question")
  
plt.xlabel("y_pred") 
plt.ylabel("y_test") 
plt.show()

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(X_train)
model = sm.OLS(y_train, x).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     Y2   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     44.20
# Date:                Sun, 21 Mar 2021   Prob (F-statistic):           9.05e-13
# Time:                        16:58:05   Log-Likelihood:                -42.621
# No. Observations:                  44   AIC:                             93.24
# Df Residuals:                      40   BIC:                             100.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2550      0.613      2.048      0.047       0.017       2.493
# ...

# %% [markdown]
# # Simple Linear Regression

# %%
x1 = chal[['X1']]
x2 = chal[['X2']]
x3 = chal[['X3']]

# %%
# Out:
# (64, 1)

# %%
X1_train, X1_test, y_train, y_test = train_test_split(x1, Y, test_size=0.3, random_state=103)

# %%
x11 = sm.add_constant(X1_train)
model = sm.OLS(y_train, x11).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     Y2   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     4.881
# Date:                Sun, 21 Mar 2021   Prob (F-statistic):             0.0327
# Time:                        17:07:59   Log-Likelihood:                -72.369
# No. Observations:                  44   AIC:                             148.7
# Df Residuals:                      42   BIC:                             152.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.7075      0.450     14.890      0.000       5.798       7.617
# ...

# %%
X2_train, X2_test, y_train, y_test = train_test_split(x1, Y, test_size=0.3, random_state=103)

# %%
x22 = sm.add_constant(X2_train)
model = sm.OLS(y_train, x22).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     Y2   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     4.881
# Date:                Sun, 21 Mar 2021   Prob (F-statistic):             0.0327
# Time:                        17:08:00   Log-Likelihood:                -72.369
# No. Observations:                  44   AIC:                             148.7
# Df Residuals:                      42   BIC:                             152.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.7075      0.450     14.890      0.000       5.798       7.617
# ...

# %%
X3_train, X3_test, y_train, y_test = train_test_split(x1, Y, test_size=0.3, random_state=103)

# %%
x33 = sm.add_constant(X3_train)
model = sm.OLS(y_train, x33).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     Y2   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     4.881
# Date:                Sun, 21 Mar 2021   Prob (F-statistic):             0.0327
# Time:                        17:08:00   Log-Likelihood:                -72.369
# No. Observations:                  44   AIC:                             148.7
# Df Residuals:                      42   BIC:                             152.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.7075      0.450     14.890      0.000       5.798       7.617
# ...

# %% [markdown]
# # Lasso Regression

# %%
from numpy import arange
from sklearn.linear_model import LassoCV
from sklearn.model_selection import RepeatedKFold

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %%
model = LassoCV(cv=cv, n_jobs=-1)

# %%
model.fit(X_train, y_train)
# Out:
# LassoCV(cv=RepeatedKFold(n_repeats=3, n_splits=10, random_state=1), n_jobs=-1)

# %%
X_train.shape
# Out:
# (44, 3)

# %%
print(model.alpha_)
# Out:
# 0.02469602651515152

# %%
y_pred = []
for i in range(X_test.shape[0]):
    y_pred.append(model.predict([X_test.iloc[i]]))

# %%
X_test.iloc[0]
# Out:
# X1    150
# X2     10
# X3     60
# Name: 42, dtype: int64

# %%
y_pred
# Out:
# [array([8.35543234]),
#  array([5.62453032]),
#  array([7.50816862]),
#  array([6.64014701]),
#  array([6.12195972]),
#  array([8.49264849]),
#  array([7.4770318]),
#  array([8.58880839]),
#  array([7.12719748]),
#  array([7.00036027]),
#  array([7.36057353]),
#  array([9.21307501]),
#  array([6.25917587]),
#  array([6.97960239]),
#  array([5.40153321]),
#  array([7.49778968]),
#  array([5.98474358]),
#  array([9.72088335]),
#  array([8.22859513]),
#  array([5.26431706])]

# %%
import sklearn.metrics as metrics
def regression_results(y_true, y_pred):

    # Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error=metrics.mean_squared_log_error(y_true, y_pred)
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)

    print('explained_variance: ', round(explained_variance,4))    
    print('mean_squared_log_error: ', round(mean_squared_log_error,4))
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

# %%
regression_results(y_test,y_pred)
# Out:
# explained_variance:  0.5863
# mean_squared_log_error:  0.0102
# r2:  0.5751
# MAE:  0.5962
# MSE:  0.6035
# RMSE:  0.7769
